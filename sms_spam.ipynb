# %% [markdown]
# <a href="https://colab.research.google.com/github/snehachavhan2004/MLfromscratch/blob/main/sms_spam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#now we have to load the dataset of spam sms classification
spam_sms = pd.read_csv("/content/spam.csv", encoding="latin-1")
spam_sms.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
# now we will take a and b dataframe to test and train
a=spam_sms.drop('v1',axis=1)
b=spam_sms['v1']

# %%
# now to split the data for testing and training we use
from sklearn.model_selection import train_test_split
a_train, a_test, b_train, b_test = train_test_split(a, b)

# now shape is used to see row and column also dimension of a,b
a_train.shape, a_test.shape, b_train.shape, b_test.shape
# Out:
# ((4179, 4), (1393, 4), (4179,), (1393,))

# %%
# now we are importing RandomForestClassifier function from sklearn module
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
